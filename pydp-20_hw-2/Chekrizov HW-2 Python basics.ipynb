# %% [markdown]
# # Домашнее задание по теме «Основы Python»
# ## Задание 1
# Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.
#
# Примеры работы программы:
#
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики’
# phrase_2 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# Результат:
# Фраза 1 длиннее фразы 2
#
# phrase_1 = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики’
# Результат:
# Фраза 2 длиннее фразы 1
#
# phrase_1 = 'Насколько проще было бы писать программы, если бы не заказчики’
# phrase_2 = 'Насколько проще было бы писать программы, если бы не заказчики’
# Результат:
# Фразы равной длины

# %%
phrase_1 = input('Введите произвольную строку: ')
# Out:
# Введите произвольную строку: А я сяду в кабриолет!

# %%
phrase_2 = input('Введите другую произвольную строку: ')
# Out:
# Введите другую произвольную строку: И уеду куда-нибудь.

# %%
if len(phrase_1) > len(phrase_2):
    print('Фраза 1 длиннее фразы 2')
elif len(phrase_1) < len(phrase_2):
    print('Фраза 2 длиннее фразы 1')
else:
    print('Фразы равной длины')
# Out:
# Фраза 1 длиннее фразы 2

# %% [markdown]
# ## Задание 2
# Дана переменная, в которой хранится четырехзначное число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.
#
# Пример работы программы:
#
# year = 2020
# Результат:
# Високосный год
#
# year = 2019
# Результат:
# Обычный год

# %%
year = int(input('Введите год: '))
if (year % 4) == 0:
    if (year % 100) !=0:
        print('Високосный год')
    elif (year % 400) == 0:
        print('Високосный год')
    else:
        print('Обычный год')
else:
    print('Обычный год')
# Out:
# Введите год: 2012
# Високосный год

# %% [markdown]
# ## Задание 3
# Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.
#
# Пример работы программы:
#
# Введите день:
# 30
#
# Введите месяц:
# Август
# Результат:
# Ваш знак зодиака: Дева
#
# Введите день:
# 29
#
# Введите месяц:
# Октябрь
# Результат:
# Ваш знак зодиака: Скорпион

# %% [markdown]
# Знак зодиака	Дата	Стихия	Планета
# 1. ♈ Овен	21 марта – 20 апреля	Огонь	Марс
# 1. ♉ Телец	21 апреля – 21 мая	Земля	Венера
# 1. ♊ Близнецы	22 мая – 21 июня	Воздух	Меркурий
# 1. ♋ Рак	22 июня – 22 июля	Вода	Луна
# 1. ♌ Лев	23 июля – 21 августа	Огонь	Солнце
# 1. ♍ Дева	22 августа – 23 сентября	Земля	Меркурий
# 1. ♎ Весы	24 сентября – 23 октября	Воздух	Венера
# 1. ♏ Скорпион	24 октября – 22 ноября	Вода	Марс, Плутон
# 1. ♐ Стрелец	23 ноября – 22 декабря	Огонь	Юпитер
# 1. ♑ Козерог	23 декабря – 20 января	Земля	Сатурн
# 1. ♒ Водолей	21 января – 19 февраля	Воздух	Сатурн, Уран
# 1. ♓ Рыбы	20 февраля – 20 марта	Вода	Юпитер, Нептун

# %%
day = int(input('Введите день: '))
month = input('Введите месяц: ')

if (month == "Декабрь" and day >=23) or (month == "Январь" and day <=20):
    print('Ваш знак зодиака: Козерог')
elif (month == "Январь" and day >=21) or (month == "Февраль" and day <=19):
    print('Ваш знак зодиака: Водолей')
elif (month == "Февраль" and day >=20) or (month == "Март" and day <=20):
    print('Ваш знак зодиака: Рыбы')
elif (month == "Март" and day >=21) or (month == "Апрель" and day <=20):
    print('Ваш знак зодиака: Овен')
elif (month == "Апрель" and day >=21) or (month == "Май" and day <=21):
    print('Ваш знак зодиака: Телец')
elif (month == "Май" and day >=22) or (month == "Июнь" and day <=21):
    print('Ваш знак зодиака: Близнецы')
elif (month == "Июнь" and day >=22) or (month == "Июль" and day <=22):
    print('Ваш знак зодиака: Рак')
elif (month == "Июль" and day >=23) or (month == "Август" and day <=21):
    print('Ваш знак зодиака: Лев')
elif (month == "Август" and day >=22) or (month == "Сентябрь" and day <=23):
    print('Ваш знак зодиака: Дева')
elif (month == "Сентябрь" and day >=24) or (month == "Октябрь" and day <=23):
    print('Ваш знак зодиака: Весы')
elif (month == "Октябрь" and day >=24) or (month == "Ноябрь" and day <=22):
    print('Ваш знак зодиака: Скорпион')
elif (month == "Ноябрь" and day >=23) or (month == "Декабрь" and day <=22):
    print('Ваш знак зодиака: Стрелец')
else:
    print('Ваш знак зодиака не определён. Ошибка ввода.')
# Out:
# Введите день: 14
# Введите месяц: Май
# Ваш знак зодиака: Телец

# %% [markdown]
# ## Задание 4
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры хранятся в переменных (в сантиметрах):
#
# width = 10
# length = 205
# height = 5
# Используйте следующие правила:
#
# если каждое из трех измерений менее 15 сантиметров, то выведите на экран “Коробка №1”;
# если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите “Коробка №2”;
# если длина товара больше 2 метров, то выводите “Упаковка для лыж”;
# во всех остальных случаях выводите “Стандартная коробка №3”.

# %%
width = int(input('Введите ширину в см.: '))
length = int(input('Введите длину в см.: '))
height = int(input('Введите высоту в см.: '))

if width <= 15 and length <= 15 and height <= 15:
    print('Коробка №1')
elif length >= 200:
    print('Упаковка для лыж')
elif (width > 15 and width <= 50) or (height > 15 and height <=50) or (length > 15 and height <=50):
    print('Коробка №2')
else:
    print('Стандартная коробка №3')
# Out:
# Введите ширину в см.: 45
# Введите длину в см.: 205
# Введите высоту в см.: 45
# Упаковка для лыж

# %% [markdown]
# ## Задание 5 (необязательное)
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет “счастливым”. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.
#
# Примеры работы программы:
#
# number = 123456
# Результат:
# Неасчастливый билет
#
# number = 123321
# Результат:
# Счастливый билет

# %%
number = int(input('Введите шестизначный номер билета: '))

if (number // 100000 % 10 == number // 1 % 10) and (number // 10000 % 10 == number // 10 % 10) and (number // 1000 % 10 == number // 100 % 10):
    print('Счастливый билет')
else:
    print('Несчастливый билет')
# Out:
# Введите шестизначный номер билета: 654456
# Счастливый билет

# %% [markdown]
# ## Задание 6 (необязательное)
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# если пользователь выбрал круг, запрашиваем его радиус,
# если треугольник – длины трех его сторон;
# если прямоугольник – длины двух его сторон.
# Пример работы программы:
#
# Введите тип фигуры:
# Круг
#
# Введите радиус круга:
# 10
# Результат:
# Площадь круга: 314.16
#
# Введите тип фигуры:
# Треугольник
#
# Введите длину стороны A:
# 2
#
# Введите длину стороны B:
# 2
#
# Введите длину стороны C:
# 3
# Результат:
# Площадь треугольника: 1.98

# %%
body_type = input('Введите тип фигуры (Круг, Треугольник, Прямоугольник): ')

if body_type == 'Круг' or body_type == 'круг':
    radius = float(input('Введите радиус круга: '))
    area = 3.14159*radius**2
    print('Площадь круга: ', area)
elif body_type == 'Треугольник' or body_type == 'треугольник':
    A_length = float(input('Введите длину стороны A: '))
    B_length = float(input('Введите длину стороны B: '))
    C_length = float(input('Введите длину стороны C: '))
    semiperimeter = (A_length + B_length + C_length)/2
    area = (semiperimeter*(semiperimeter-A_length)*(semiperimeter-B_length)*(semiperimeter-C_length))**(1/2)
    print('Площадь треугольника: ', area)
elif body_type == 'Прямоугольник' or body_type == 'прямоугольник':
    A_length = float(input('Введите длину стороны A: '))
    B_length = float(input('Введите длину стороны B: '))
    area = A_length*B_length
    print('Площадь прямоугольника: ', area)
# Out:
# Введите тип фигуры (Круг, Треугольник, Прямоугольник): Треугольник
# Введите длину стороны A: 2
# Введите длину стороны B: 2
# Введите длину стороны C: 3
# Площадь треугольника:  1.984313483298443
